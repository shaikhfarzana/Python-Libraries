# %%
"""
@Author: Farzana Shaikh
@Date: 20-01-2021 08:00PM
@Last Modified by: Farzana Shaikh
@Last Modified time: 22-01-2022 03:00PM
@Title : Mathplotlib Bargraph Problems.
"""

# %% [markdown]
# 1. Write a Python programming to display a bar chart of the popularity of programming Languages.

# %%
import matplotlib.pyplot as plt

def to_display_bar_chart():
    """
       Description:
          Function is used to display a bar chart.
       Parameter:
          No parameter required.
       Return:
          Returns nothing.
    """
    x = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
    popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
    x_pos = [i for i, _ in enumerate(x)]
    plt.bar(x_pos, popularity, color='cornflowerblue')
    plt.xlabel("Languages", color='cyan')
    plt.ylabel("Popularity",color='cyan')
    plt.title("PopularitY of Programming Language\n" + "Worldwide, Oct 2017 compared to a year ago", color='cyan')
    plt.xticks(x_pos, x, color='cyan')
    plt.yticks(color='cyan')
    plt.show()

if __name__ == "__main__":
    to_display_bar_chart()

# %% [markdown]
# 2.Write a Python programming to display a horizontal bar chart of the popularity of programming Languages.

# %%
import matplotlib.pyplot as plt

def to_display_horizontal_barchart():
    """
       Description:
          Function is used to display horizontal bar chart.
       Parameter:
          No parameter required.
       Return:
          Returns nothing.
    """
    x = ['Java', 'Python', 'PHP', 'JS', 'C#', 'C++']
    popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
    x_pos = [i for i, _ in enumerate(x)]
    plt.barh(x_pos, popularity, color='deepskyblue')
    plt.xlabel("Languages", color='cyan')
    plt.ylabel("Popularity",color='cyan')
    plt.title("PopularitY of Programming Language\n" + "Worldwide, Oct 2017 compared to a year ago", color='cyan')
    plt.xticks(color='cyan')
    plt.yticks(x_pos, x, color='cyan')
    # Turn on the grid
    plt.minorticks_on()
    plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')
    # Customize the minor grid
    plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
    plt.show()

if __name__ == "__main__":
    to_display_horizontal_barchart()

# %% [markdown]
# 3.​ Write a Python programming to display a bar chart of the popularity of programming Languages. Use uniform color.

# %%
import matplotlib.pyplot as plt

def to_display_uniform_color_bargraph():
    """
       Description:
          Function is used to display a bar chart of Uniform color .
       Parameter:
          No parameter required.
       Return:
          Returns nothing.
    """
    x = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
    popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
    x_pos = [i for i, _ in enumerate(x)]

    plt.bar(x_pos, popularity, color='coral')
    plt.xlabel("Languages", color='cyan')
    plt.ylabel("Popularity",color='cyan')
    plt.title("PopularitY of Programming Language\n" + "Worldwide, Oct 2017 compared to a year ago", color='cyan')
    plt.xticks(x_pos, x, color='cyan')
    plt.yticks(color='cyan')
    plt.minorticks_on()
    plt.grid(which='major', linestyle='-', linewidth='0.5', color='violet')
    # Customize the minor grid
    plt.grid(which='minor', linestyle=':', linewidth='0.5', color='darkcyan')
    plt.show()

if __name__ == "__main__":
    to_display_uniform_color_bargraph()

# %% [markdown]
# 4.​ Write a Python programming to display a bar chart of the popularity of programming Languages. Use different color for each bar.

# %%
import matplotlib.pyplot as plt

def to_display_different_color_bargraph():
    """
       Description:
          Function is used to display a bar chart of different color .
       Parameter:
          No parameter required.
       Return:
          Returns nothing.
    """
    x = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
    popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
    x_pos = [i for i, _ in enumerate(x)]

    plt.bar(x_pos, popularity, color=['darkorange', 'darkgoldenrod', 'coral', 'darkmagenta', 'deeppink', 'cyan'])
    plt.xlabel("Languages", color='cyan')
    plt.ylabel("Popularity",color='cyan')
    plt.title("PopularitY of Programming Language\n" + "Worldwide, Oct 2017 compared to a year ago", color='cyan')
    plt.xticks(x_pos, x, color='cyan')
    plt.yticks(color='cyan')
    plt.minorticks_on()
    plt.grid(which='major', linestyle='-', linewidth='0.5', color='violet')
    # Customize the minor grid
    plt.grid(which='minor', linestyle=':', linewidth='0.5', color='darkcyan')
    plt.show()

if __name__ == "__main__":
    to_display_different_color_bargraph()

# %% [markdown]
# 5.​ Write a Python programming to display a bar chart of the popularity of programming Languages. Attach a text label above each bar displaying its popularity (float value).

# %%
import matplotlib.pyplot as plt

def attach_label_to_bargraph():
    """
       Description:
          Function is used to attach text label above the bargraph.
       Parameter:
          No parameter required.
       Return:
          Returns nothing.
    """
x = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
x_pos = [i for i, _ in enumerate(x)]

fig, ax = plt.subplots()
rects1 = ax.bar(x_pos, popularity, color='darkslategray')
plt.xlabel("Languages", color='cyan')
plt.ylabel("Popularity",color='cyan')
plt.title("PopularitY of Programming Language\n" + "Worldwide, Oct 2017 compared to a year ago", color='cyan')
plt.xticks(x_pos, x, color='cyan')
plt.yticks(color='cyan')
# Turn on the grid
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')
# Customize the minor grid
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
def autolabel(rects):
# Attach a text label above each bar displaying its height

   for rect in rects:
            height = rect.get_height()
            ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
                  '%f' % float(height),
            ha='center', va='bottom')
autolabel(rects1)

plt.show()

if __name__ == "__main__":
     attach_label_to_bargraph()

# %% [markdown]
# 6.​ Write a Python programming to display a bar chart of the popularity of programming Languages. Make blue border to each bar.

# %%
import matplotlib.pyplot as plt

def to_display_colorborder_on_bar():
    """
       Description:
          Function is used to display a bar chart with Blue border on each bar.
       Parameter:
          No parameter required.
       Return:
          Returns nothing.
    """
    x = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
    popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
    x_pos = [i for i, _ in enumerate(x)]

    plt.bar(x_pos, popularity, color='gold', edgecolor='blue')
    plt.xlabel("Languages", color='cyan')
    plt.ylabel("Popularity",color='cyan')
    plt.title("PopularitY of Programming Language\n" + "Worldwide, Oct 2017 compared to a year ago", color='cyan')
    plt.xticks(x_pos, x, color='cyan')
    plt.yticks(color='cyan')
    plt.minorticks_on()
    plt.grid(which='major', linestyle='-', linewidth='0.5', color='violet')
    # Customize the minor grid
    plt.grid(which='minor', linestyle=':', linewidth='0.5', color='darkcyan')
    plt.show()

if __name__ == "__main__":
    to_display_colorborder_on_bar()

# %% [markdown]
# 7.​ Write a Python programming to display a bar chart of the popularity of programming Languages. Specify the position of each bar plot.

# %%
import matplotlib.pyplot as plt

def to_specify_bar_plots():
    """
       Description:
          Function is used to specify position for bar plots.
       Parameter:
          No parameter required.
       Return:
          Returns nothing.
    """
    x = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
    popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
    x_pos = [i for i, _ in enumerate(x)]

    plt.xlabel("Languages", color='cyan')
    plt.ylabel("Popularity",color='cyan')
    plt.title("PopularitY of Programming Language\n" + "Worldwide, Oct 2017 compared to a year ago", color='cyan')
    plt.xticks(x_pos, x, color='cyan')
    plt.yticks(color='cyan')
    y_pos = [0,1,4,7,9,10]
    # Create bars
    plt.bar(y_pos, popularity, color='darkorchid')
    plt.minorticks_on()
    plt.grid(which='major', linestyle='-', linewidth='0.5', color='violet')
    # Customize the minor grid
    plt.grid(which='minor', linestyle=':', linewidth='0.5', color='darkcyan')
    plt.show()

if __name__ == "__main__":
    to_specify_bar_plots()

# %% [markdown]
# 8.Write a Python programming to display a bar chart of the popularity of programming Languages. Select the width of each bar and their positions.

# %%
import matplotlib.pyplot as plt

def to_specify_width_of_bar_plot():
    """
       Description:
          Function is used to specify position and width of bar plots.
       Parameter:
          No parameter required.
       Return:
          Returns nothing.
    """
    x = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
    popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
    x_pos = [i for i, _ in enumerate(x)]

    plt.xlabel("Languages", color='cyan')
    plt.ylabel("Popularity",color='cyan')
    plt.title("PopularitY of Programming Language\n" + "Worldwide, Oct 2017 compared to a year ago", color='cyan')
    plt.xticks(x_pos, x, color='cyan')
    plt.yticks(color='cyan')
    width = [0.1,0.2,0.5,2.1,0.2,0.3]
    y_pos = [0,1,4,7,9,10]
    # Create bars
    plt.bar(y_pos, popularity, color='dodgerblue', width=width)
    plt.minorticks_on()
    plt.grid(which='major', linestyle='-', linewidth='0.5', color='violet')
    # Customize the minor grid
    plt.grid(which='minor', linestyle=':', linewidth='0.5', color='darkcyan')
    plt.show()

if __name__ == "__main__":
    to_specify_width_of_bar_plot()

# %% [markdown]
# 9.Write a Python programming to display a bar chart of the popularity of programming Languages. Increase bottom margin.

# %%
import matplotlib.pyplot as plt

def to_increase_bottom_margin():
    """
       Description:
          Function is used to display a bar chart. Increase bottom margin.
       Parameter:
          No parameter required.
       Return:
          Returns nothing.
    """
    x = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
    popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
    x_pos = [i for i, _ in enumerate(x)]

    plt.bar(x_pos, popularity, color='olive')
    plt.xlabel("Languages", color='cyan')
    plt.ylabel("Popularity",color='cyan')
    plt.title("PopularitY of Programming Language\n" + "Worldwide, Oct 2017 compared to a year ago", color='cyan')
    plt.xticks(x_pos, x, rotation=90, color='cyan')
    plt.yticks(color='cyan')
    plt.subplots_adjust(bottom=0.4, top=0.8)
    plt.minorticks_on()
    plt.grid(which='major', linestyle='-', linewidth='0.5', color='violet')
    # Customize the minor grid
    plt.grid(which='minor', linestyle=':', linewidth='0.5', color='darkcyan')
    plt.show()

if __name__ == "__main__":
    to_increase_bottom_margin()

# %% [markdown]
# 10.Write a Python program to create bar plot of scores by group and gender. Use multiple X
# values on the same chart for men and women.

# %%
import numpy as np
import matplotlib.pyplot as plt

def to_plot_multiple_charts():
    """
       Description:
          Function is used to plot multiple bar charts.
       Parameter:
          No parameter required.
       Return:
          Returns nothing.
    """
# data to plot
    n_groups = 5
    men_means = (22, 30, 33, 30, 26)
    women_means = (25, 32, 30, 35, 29)

    # create plot
    fig, ax = plt.subplots()
    index = np.arange(n_groups)
    bar_width = 0.35
    opacity = 0.8

    rects1 = plt.bar(index, men_means, bar_width, alpha=opacity, color='lightcoral', label='Men')

    rects2 = plt.bar(index + bar_width, women_means, bar_width, alpha=opacity, color='teal', label='Women')

    plt.xlabel('Person', color='cyan')
    plt.ylabel('Scores',color='cyan')
    plt.title('Scores by person', color='cyan')
    plt.xticks(index + bar_width, ('G1', 'G2', 'G3', 'G4', 'G5'),color='cyan')
    plt.yticks(color='cyan')
    plt.legend()

    plt.tight_layout()
    plt.show()

if __name__ == "__main__":
    to_plot_multiple_charts()

# %% [markdown]
# 11.Write a Python program to create bar plot from a DataFrame.

# %%
from pandas import DataFrame
import matplotlib.pyplot as plt
import numpy as np

def barplot_from_dataframe():
    """
       Description:
          Function is used to create Bar chart from Dataframe.
       Parameter:
          No parameter required.
       Return:
          Returns nothing.
    """

    a=np.array([[4,8,5,7,6],[2,3,4,2,6],[4,7,4,7,8],[2,6,4,8,6],[2,4,3,3,2]])
    df=DataFrame(a, columns=['a','b','c','d','e'], index=[2,4,6,8,10])

    df.plot(kind='bar')
    # Turn on the grid
    plt.minorticks_on()
    plt.xticks(color='cyan')
    plt.yticks(color='cyan')
    plt.title('Bar Chart From Dataframe', color='cyan')
    plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
    plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')

    plt.show()

if __name__ == "__main__":
    barplot_from_dataframe()

# %% [markdown]
# 12.​Write a Python program to create bar plots with error bars on the same figure.

# %%
import numpy as np
import matplotlib.pyplot as plt


def barplot_with_error_bars():
    """
       Description:
          Function is used to create bar charts with error bars.
       Parameter:
          No parameter required.
       Return:
          Returns nothing.
    """
    N = 5
    menMeans = (54.74, 42.35, 67.37, 58.24, 30.25)
    menStd = (4, 3, 4, 1, 5)
    # the x locations for the groups
    index = np.arange(N)    
    # the width of the bars
    width = 0.35   
    plt.bar(index, menMeans, width, yerr=menStd, color='seagreen')
    plt.ylabel('Scores', color='cyan')
    plt.xlabel('Velocity', color='cyan')
    plt.title('Scores by Velocity', color='cyan')
    # Turn on the grid
    plt.minorticks_on()
    plt.xticks(color='cyan')
    plt.yticks(color='cyan')

    plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
    plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')

    plt.show()

if __name__ == "__main__":
    barplot_with_error_bars()

# %% [markdown]
# 13.Write a Python program to create bar plots with errorbars on the same figure. Attach a text label above each bar displaying men means (integer value).

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

def text_label_above_bargraph():
    """
       Description:
          Function is used to create bar graph with text lable above each bars.
       Parameter:
          No parameter required.
       Return:
          Returns nothing.
    """
    N = 5
    men_means = (54.74, 42.35, 67.37, 58.24, 30.25)
    men_std= (4, 3, 4, 1, 5)

    index = np.arange(N)  # the x locations for the groups
    width = 0.35       # the width of the bars

    fig, ax = plt.subplots()
    rects1 = ax.bar(index, men_means, width, color='tan', yerr=men_std)

    # add some text for labels, title and axes ticks
    plt.ylabel('Scores', color='cyan')
    plt.xlabel('Velocity', color='cyan')
    plt.title('Scores by Velocity', color='cyan')
    plt.xticks(color='cyan')
    plt.yticks(color='cyan')

    red_patch = mpatches.Patch(color='red', label='Men')
    plt.legend(handles=[red_patch])


    def autolabel(rects):
        """
        Attach a text label above each bar displaying its height
        """
        for rect in rects:
            height = rect.get_height()
            ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
                        '%d' % int(height),
            ha='center', va='bottom')
    autolabel(rects1)
    plt.show()

if __name__ == "__main__":
    text_label_above_bargraph()
