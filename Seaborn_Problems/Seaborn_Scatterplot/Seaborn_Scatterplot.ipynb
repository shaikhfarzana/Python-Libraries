# %% [markdown]
# """
# @Author: Farzana Shaikh
# @Date: 23-01-2021 08:00AM
# @Last Modified by: Farzana Shaikh
# @Last Modified time: 24-01-2022 09:00AM
# @Title : Seaborn Scatterplot Problems.
# """

# %% [markdown]
# 1.Write a program to draw a scatter plot of “day” against “total bill” for a dataset given in a url

# %%
from matplotlib import pyplot as plt
import seaborn as sns

def draw_scatter_plot():
    """
       Description:
          Function is used to draw a scatter plot for a given dataset.
       Parameter:
          No parameter required.
       Return:
          Returns nothing.
    """
    sns.set_style('whitegrid')
    # Import Data
    tips_dataset = sns.load_dataset("tips")
    plt.scatter(x = "day", y = "total_bill", color = "magenta" ,data = tips_dataset)
    sns.relplot(x="total_bill", y="tip", hue="day", data = tips_dataset)
    plt.show()

if __name__ == "__main__":
    draw_scatter_plot()

# %% [markdown]
# """
# @Author: Farzana Shaikh
# @Date: 23-01-2021 08:00AM
# @Last Modified by: Farzana Shaikh
# @Last Modified time: 24-01-2022 09:00AM
# @Title : Seaborn Scatterplot Problems.
# """

# %% [markdown]
# <!-- SEABORN VIOLIN PLOT -->

# %% [markdown]
# 1.Write a program to draw a violin plot of sex against​ total_bill​ for a given dataset.

# %%
from matplotlib import pyplot as plt
import seaborn as sns

def draw_swarm_plot():
    """
       Description:
          Function is used to draw a violin plot for a given dataset.
       Parameter:
          No parameter required.
       Return:
          Returns nothing.
    """
    sns.set_style('whitegrid')
    # Import Data
    tips_dataset = sns.load_dataset("tips")
    sns.violinplot(x = "sex", y = "total_bill", color = "deepskyblue" ,data = tips_dataset)
    plt.show()

if __name__ == "__main__":
    draw_swarm_plot()

# %% [markdown]
# 2.Write a program to draw a violin plot of “species” against “sepal length” for a dataset given in a url

# %%
from matplotlib import pyplot as plt
import seaborn as sns

def draw_violin_plot():
    """
       Description:
          Function is used to draw a violin plot for a given dataset.
       Parameter:
          No parameter required.
       Return:
          Returns nothing.
    """
    sns.set_style('whitegrid')
    # Import Data
    iris_dataset = sns.load_dataset("iris")
    sns.violinplot(x = "species", y = "sepal_length", color = "slateblue" ,data = iris_dataset)
    plt.show()

if __name__ == "__main__":
    draw_violin_plot()

# %% [markdown]
# """
# @Author: Farzana Shaikh
# @Date: 23-01-2021 08:00AM
# @Last Modified by: Farzana Shaikh
# @Last Modified time: 24-01-2022 09:00AM
# @Title : Seaborn Swarmplot Problems.
# """

# %% [markdown]
# <!-- SWARMPLOT -->

# %% [markdown]
# 1.Write a program to draw a swarm plot of total bill against size for a given dataset.

# %%
from matplotlib import pyplot as plt
import seaborn as sns

def draw_swarm_plot():
    """
       Description:
          Function is used to draw a swarm plot for a given dataset.
       Parameter:
          No parameter required.
       Return:
          Returns nothing.
    """
    sns.set_style('whitegrid')

    # Import Data
    tips_dataset = sns.load_dataset("tips")

    sns.swarmplot(x="total_bill", y="size", data=tips_dataset)
    plt.show()

if __name__ == "__main__":
    draw_swarm_plot()
# Out:
# /home/user/.local/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/user/.local/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 66.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
